# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics
import warnings
warnings.filterwarnings("ignore")
sns.set_style("darkgrid")
sns.set(font = "arial")
mx= [[1,2],
     [2,6]]
covar = np.matrix(mx)

# %%
vector_ = []
for _ in range(1000):
    vector = np.random.multivariate_normal(mean=[0 for _ in range(2)], cov = covar)
    vector_.append(vector)

vector_t = np.transpose(vector_)
covar = np.cov(np.transpose(vector_))

covar
# Out:
# array([[0.97419982, 1.97775769],
#        [1.97775769, 5.8865751 ]])

# %%
plt.scatter(x = vector_t[0],y=vector_t[1])
plt.ylim(-10,10)
plt.xlim(-10,10)
# Out:
# (-10.0, 10.0)

# %%
mx= covar
lambda_, v = np.linalg.eig(mx)
lambda_ = np.sqrt(lambda_)

lambda_
v
# Out:
# array([[-0.94310225, -0.33250286],
#        [ 0.33250286, -0.94310225]])

# %%
def get_ellipse(mx=None,center= None, sigma = 1):
    mean_x = center[0]
    mean_y=  center[1]
    lambda_, v = np.linalg.eig(mx) ## Eigenvalues and normalized Eigenvectors
    lambda_ = np.sqrt(lambda_)
    ell = Ellipse(xy=(mean_x, mean_y),
                width=lambda_[0]*sigma, height=lambda_[1]*sigma,
                angle=np.rad2deg(np.arccos(v[0, 0])))
    ell.set_facecolor('none')
    ell.set_edgecolor("black")
    ell.set_linewidth(0.3)
    ell.set_linestyle("-.")

# %%
a,b = -0.96664178, -0.25613212
c = a*a+b*b
c
# Out:
# 0.9999999937372628
